# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
## prompt -> llm -> detailed Report -> llm -> 5 imp points

# %%
prompt1 = PromptTemplate(
    template='Generate a detailed Report on {topic}',
    input_variables=['topic']
)

# %%
prompt2 = PromptTemplate(
    template='Give 5 important points from the report {report}',
    input_variables=['report']
)

# %%
llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.1-8B-Instruct",
    task="text-generation"
)

model = ChatHuggingFace(llm=llm)

# %%
parser = StrOutputParser()

# %%
chain = prompt1 | model | parser | prompt2 | model | parser

# %%
result = chain.invoke({'topic':'Blackhole'})

# %%
print(result)
# Out:
# Here are **five important points** from the **Comprehensive Report on Black Holes**:
#
# 1. **Formation from Stellar Collapse**
#    - Stellar black holes form when massive stars (20+ solar masses) collapse after a supernova, exceeding the Chandrasekhar limit.
#
# 2. **Supermassive Black Holes (SMBHs) at Galaxy Centers**
#    - SMBHs reside at galactic cores, possibly forming from direct gas collapse, mergers, or quasar-driven growth in the early universe.
#
# 3. **Event Horizon and Singularity**
#    - The event horizon marks the point of no return (Schwarzschild radius), while the singularity is a theorized center of infinite density.
#
# 4. **Accretion Disks and Relativistic Jets**
#    - Matter spiraling into black holes forms hot accretion disks, emitting X-rays, while some produce high-speed jets (e.g., in quasars).
#
# 5. **Primordial and Intermediate Black Holes**
#    - Hypothetical primordial black holes may have formed from quantum fluctuations early in cosmic history, while intermediate-mass black holes (IMBHs) could arise from star cluster mergers.
#
# These points highlight key aspects of black hole physics, formation, and observational phenomena.

# %%
print(chain.get_graph().print_ascii())
# Out:
#      +-------------+
#      | PromptInput |
#      +-------------+
#             *
#             *
#             *
#     +----------------+
#     | PromptTemplate |
#     +----------------+
#             *
#             *
#             *
#    +-----------------+
#    | ChatHuggingFace |
#    +-----------------+
#             *
#             *
#             *
#    +-----------------+
#    | StrOutputParser |
#    +-----------------+
#             *
#             *
#             *
# +-----------------------+
# | StrOutputParserOutput |
# +-----------------------+
#             *
#             *
#             *
#     +----------------+
#     | PromptTemplate |
#     +----------------+
#             *
#             *
#             *
#    +-----------------+
#    | ChatHuggingFace |
#    +-----------------+
#             *
#             *
#             *
#    +-----------------+
#    | StrOutputParser |
#    +-----------------+
#             *
#             *
#             *
# +-----------------------+
# | StrOutputParserOutput |
# +-----------------------+
# None
