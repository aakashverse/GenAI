# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gemma3:1b")

# %%
res = llm.invoke("Hello, I am Aakash.")
res.content
# Out:
# 'Hello Aakash! It’s nice to meet you. How can I help you today? 😊 \n\nIs there anything you’d like to talk about, or perhaps you’d like me to do something like:\n\n*   Answer a question?\n*   Write something for you?\n*   Just chat?'
