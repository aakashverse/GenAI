# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
prompt = PromptTemplate(
    template='Generate 5 interesting facts about {topic}',
    input_variables=['topic']
)

# %%
llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.1-8B-Instruct",
    task="text-generation"
)

model = ChatHuggingFace(llm=llm)

# %%
parser = StrOutputParser()

# %%
chain = prompt | model | parser

# %%
result = chain.invoke({'topic':'cricket'})

# %%
print(result)
# Out:
# Here are five interesting facts about cricket that you might enjoy:
#
# 1. **The Longest Cricket Match Ever Played**
#    The longest recorded cricket match lasted **14 days** (from February 18 to March 24, 1890) between **England and Australia** in a Test match at Melbourne. The match ended in a draw after 7 days of play. Modern Test matches are now limited to a maximum of 5 days.
#
# 2. **The Smallest Number of Runs in a Test Match**
#    The lowest total in a Test innings is **26** by **South Africa** against **England** in 1924. They were bowled out in just **56 minutes** (12.3 overs). The lowest Twenty20 score is **21** by **Netherlands** against **Sri Lanka** in 2014.
#
# 3. **The First-Ever International Cricket Match**
#    The first official international cricket match was played between **the USA and Canada on September 24, 1844**, at the St. George’s Cricket Club in New York. The USA won by 23 runs.
#
# 4. **The Highest Individual Score in International Cricket**
#    The highest individual score in any international match is **429** by **Brian Lara** for the **West Indies** against **England** in a 2004 Test match. In ODIs, the record is **264** by **Rohit Sharma** (India vs Sri Lanka, 2014).
#
# 5. **Cricket’s Mysterious Origins**
#    The exact origins of cricket are unclear, but it is believed to have originated in **16th-century England**. One theory suggests it evolved from a children’s game called **"creag"** (Old English for "stick"). The sport was first played with a curved stick and a ball, resembling modern-day hockey.
#
# Would you like more facts on a specific aspect of cricket?

# %%
chain.get_graph().print_ascii()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 chain.get_graph().print_ascii()
#
# File c:\Users\hp\OneDrive\Desktop\GenAI\env\Lib\site-packages\langchain_core\runnables\graph.py:523, in Graph.print_ascii(self)
#     521 def print_ascii(self) -> None:
#     522     """Print the graph as an ASCII art string."""
# --> 523     print(self.draw_ascii())
#
# File c:\Users\hp\OneDrive\Desktop\GenAI\env\Lib\site-packages\langchain_core\runnables\graph.py:516, in Graph.draw_ascii(self)
#     513 # Import locally to prevent circular import
#     514 from langchain_core.runnables.graph_ascii import draw_ascii  # noqa: PLC0415
# --> 516 return draw_ascii(
#     517     {node.id: node.name for node in self.nodes.values()},
#     518     self.edges,
#     519 )
#
# File c:\Users\hp\OneDrive\Desktop\GenAI\env\Lib\site-packages\langchain_core\runnables\graph_ascii.py:299, in draw_ascii(vertices, edges)
#     296 xlist: list[float] = []
#     297 ylist: list[float] = []
# --> 299 sug = _build_sugiyama_layout(vertices, edges)
#     301 for vertex in sug.g.sV:
#     302     # NOTE: moving boxes w/2 to the left
#     303     xlist.extend(
#     304         (
#     305             vertex.view.xy[0] - vertex.view.w / 2.0,
#     306             vertex.view.xy[0] + vertex.view.w / 2.0,
#     307         )
#     308     )
#
# File c:\Users\hp\OneDrive\Desktop\GenAI\env\Lib\site-packages\langchain_core\runnables\graph_ascii.py:206, in _build_sugiyama_layout(vertices, edges)
#     204 if not _HAS_GRANDALF:
#     205     msg = "Install grandalf to draw graphs: `pip install grandalf`."
# --> 206     raise ImportError(msg)
#     208 #
#     209 # Just a reminder about naming conventions:
#     210 # +------------X
#    (...)    215 # Y
#     216 #
#     218 vertices_ = {id_: Vertex(f" {data} ") for id_, data in vertices.items()}
#
# ImportError: Install grandalf to draw graphs: `pip install grandalf`.
